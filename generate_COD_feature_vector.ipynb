# %% [markdown]
# This code will generate the feature vector, using sub grids to calculate the overlap

# %%
import pandas as pd
#pd.set_option('display.max_rows', None)
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import cartopy.crs as ccrs
import cartopy
import numpy as np
import netCDF4 as nc
np.set_printoptions(threshold=100000)
from shapely.geometry import Polygon, Point, MultiPoint
from shapely.ops import cascaded_union
from datetime import datetime, timedelta
import time
import warnings
warnings.filterwarnings('ignore')
from joblib import Parallel, delayed

# %% [markdown]
# ##  Step 0. Throw out fires that have 0 viirs detects on any day. (fires are already filtered to be in the right lat/lon range

# %%
# load in the polygons and attributes
fire_polygons = gpd.read_file('fire_polygons_only.geojson')
fire_attributes = pd.read_csv('fire_polygons_attributes.csv')
incidents = pd.read_csv('unique_fires.csv')
print(len(fire_polygons), len(fire_attributes), len(incidents))

#throw out fires that have 0 days with detects
daily_drop_inds = []
incident_drop_inds = []
for item in incidents['Incident Number']:
    pts = fire_attributes['Number of VIIRS points'].values[fire_attributes['Incident Number']==item]
    if len(pts[pts==0])==len(pts):
        #print(item, 'oops all zeros')
        daily_drop_inds = np.append(daily_drop_inds, np.where(fire_attributes['Incident Number']==item)[0])
        incident_drop_inds = np.append(incident_drop_inds, np.where(incidents['Incident Number']==item)[0])

daily_drop_inds = [int(p) for p in daily_drop_inds]
#print(daily_drop_inds)

fire_attributes = fire_attributes.drop(labels= daily_drop_inds)
fire_attributes = fire_attributes.drop(labels='Unnamed: 0', axis=1)
fire_polygons = fire_polygons.drop(labels = daily_drop_inds)
incidents = incidents.drop(labels = incident_drop_inds)
print(len(fire_polygons), len(fire_attributes), len(incidents))

fire_attributes
# Out:
# 22280 22280 1354
# 19137 19137 1036
#        Incident Number      Fire Name Current Day   Lat Fire    Lon Fire  \
# 5           10662684.0  PAINTED WAGON  2019-04-08  33.786944 -112.753333
# 6           10662684.0  PAINTED WAGON  2019-04-09  33.786944 -112.753333
# 7           10662684.0  PAINTED WAGON  2019-04-10  33.786944 -112.753333
# 8           10663171.0  LONE MOUNTAIN  2019-05-26  33.808056 -105.738611
# 9           10663171.0  LONE MOUNTAIN  2019-05-27  33.808056 -105.738611
# ...                ...            ...         ...        ...         ...
# 22275       11980587.0        CREEK 5  2020-12-25  33.402646 -117.266795
# 22276       11980587.0        CREEK 5  2020-12-26  33.402646 -117.266795
# 22277       11980587.0        CREEK 5  2020-12-27  33.402646 -117.266795
# 22278       11980587.0        CREEK 5  2020-12-28  33.402646 -117.266795
# 22279       11980949.0        CREEK 5  2020-12-24  33.407667 -117.269667
#
#        Number of VIIRS points
# 5                         3.0
# 6                         0.0
# 7                         0.0
# 8                         0.0
# 9                         0.0
# ...                       ...
# 22275                    16.0
# 22276                     0.0
# 22277                     0.0
# 22278                     0.0
# 22279                     2.0
#
# [19137 rows x 6 columns]

# %% [markdown]
# ## 1. Figure out the start and end date we will use for each fire

# %%
# first check what fraction of the fire lifetimes are 0 days
for item in incidents['Incident Number']:
    pts = fire_attributes['Number of VIIRS points'].values[fire_attributes['Incident Number']==item]
    #print(len(np.where(pts==0)[0]))
    print('The fire lifetime is ', len(np.where(pts!=0)[0])*100/len(pts), '% nonzero detections')

# %%
keep_days = []
for item in incidents['Incident Number']:
    pts = fire_attributes['Number of VIIRS points'].values[fire_attributes['Incident Number']==item]
    dys = fire_attributes['Current Day'].values[fire_attributes['Incident Number']==item]
    nonzero = np.where(pts!=0)[0]
    first_day = dys[nonzero[0]]
    last_day = dys[nonzero[len(nonzero)-1]]
    keep_days = np.append(keep_days, np.where((fire_attributes['Incident Number']==item)&(fire_attributes['Current Day']>=first_day)&(fire_attributes['Current Day']<=last_day))[0])

keep_days = [int(p) for p in keep_days]
print(len(keep_days))
fire_attributes = fire_attributes.iloc[keep_days, :]
fire_polygons = fire_polygons.iloc[keep_days, :]
fire_attributes = fire_attributes.reset_index(drop=True) #reset the indices beecause we dropped some
fire_polygons = fire_polygons.reset_index(drop=True) #reset the indices beecause we dropped some

fire_polygons
# Out:
# 8161
#                                                geometry
# 0     POLYGON ((-112.75455 33.78632, -112.76012 33.7...
# 1     POLYGON ((-105.73275 33.80235, -105.73861 33.8...
# 2     POLYGON ((-105.73275 33.80235, -105.73861 33.8...
# 3     POLYGON ((-105.73275 33.80235, -105.73861 33.8...
# 4     POLYGON ((-105.73275 33.80235, -105.73861 33.8...
# ...                                                 ...
# 8156  POLYGON ((-112.11669 34.11898, -112.12564 34.1...
# 8157  POLYGON ((-117.03702 33.90632, -117.04484 33.9...
# 8158  POLYGON ((-117.27595 33.37881, -117.27495 33.3...
# 8159  POLYGON ((-117.29549 33.36558, -117.29713 33.4...
# 8160  POLYGON ((-117.27595 33.37881, -117.26967 33.4...
#
# [8161 rows x 1 columns]

# %% [markdown]
# ## 2. Loop through the days and get the raw features (temp at different pressure levels, wind, pressure, precip, terrain info) and the labels (QFED PM2.5 from the next day)

# %%
# THIS WAY IS PRETTY SLOW

#pre-allocate the data frame
num_days = len(fire_attributes)
fire_features = gpd.GeoDataFrame({'Incident Number': np.nan*np.zeros(num_days), 
                          'Fire Name': np.nan*np.zeros(num_days), 
                         'Current Day': np.nan*np.zeros(num_days),
                        'Lat Fire': np.nan*np.zeros(num_days), 
                     'Lon Fire': np.nan*np.zeros(num_days), 
                         'Number of VIIRS points': np.nan*np.zeros(num_days),
                        'TLML': np.nan*np.zeros(num_days), 
                        'QLML': np.nan*np.zeros(num_days),
                                  'SPEEDLML': np.nan*np.zeros(num_days),
                                  'PS': np.nan*np.zeros(num_days),
            'geometry': np.nan*np.zeros(num_days)}) # pre-allocate the dataframe

fire_features['Incident Number'] = fire_attributes['Incident Number'].values
fire_features['Fire Name'] = fire_attributes['Fire Name'].values
fire_features['Current Day'] = fire_attributes['Current Day'].values
fire_features['Lat Fire'] = fire_attributes['Lat Fire'].values
fire_features['Lon Fire'] = fire_attributes['Lon Fire'].values
fire_features['Number of VIIRS points'] = fire_attributes['Number of VIIRS points'].values
fire_features['geometry'] = fire_polygons['geometry'].values

varis = {'WESTUS_MERRA2_400.inst1_2d_lfo_Nx.':['TLML', 'QLML', 'SPEEDLML', 'PS']}
locs = {'WESTUS_MERRA2_400.inst1_2d_lfo_Nx.':['lat', 'lon']}
subfolders = {'/MERRA2/'}
file_suffix = '.nc4'

for ii in range(num_days): #loop over all the days
    #get the day
    year = fire_features['Current Day'][ii][0:4]
    month = fire_features['Current Day'][ii][5:7]
    day = fire_features['Current Day'][ii][8:10]
    #print(year, month, day)
    
    for folder in subfolders:
        path = '/data2/lthapa/'+str(year)+folder
        #print(path)
        
        #THIS COULD BE A SEPARATE HELPER FUNCTION
        for file_prefix in varis.keys(): # for each dataset
            path = path+file_prefix+year+month+day+file_suffix
            print(path)
            dataset = nc.Dataset(path)
            
            #get the lat and lon for the dataset
            loc_vals = []
            for loc in locs.values():
                loc_vals.append(loc)
            loc_vals = loc_vals[0]
            lat = dataset[loc_vals[0]][:]
            lon = dataset[loc_vals[1]][:]
            #turn it into a meshgrid
            LON, LAT = np.meshgrid(lon, lat)
            #get the full variable, put it to daily resolution
            for value in varis.values(): 
                for var in value:
                    variable = dataset[var][:]
                    variable = np.nanmean(variable, axis=0) #average across the day
                    #print(variable.shape, LON.shape, LAT.shape)
            
                    #find the intersection
                    overlaps = calculate_overlaps(LAT, LON, fire_features['geometry'][ii])
                    variable_weighted = np.multiply(variable,overlaps)
                    #save it to the dataframe
                    fire_features.loc[ii, var] = np.nansum(variable_weighted)
fire_features
# Out:
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190408.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190609.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190610.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190611.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190612.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190613.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190614.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190615.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190616.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190617.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190618.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190619.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190620.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190621.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190622.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190623.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190624.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190625.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190626.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190627.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190628.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190629.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190630.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190701.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190702.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190514.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190405.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190606.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190607.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190313.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190519.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190520.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190521.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190522.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190523.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190524.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190525.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190526.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190527.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190528.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190529.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190530.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190531.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190601.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190602.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190603.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190604.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190605.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190606.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190607.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190608.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190607.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190608.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190609.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190610.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190611.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190612.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190613.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190614.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190615.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190704.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190705.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190706.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190707.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190708.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190709.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190710.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190711.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190530.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190531.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190601.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190602.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190603.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190604.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190605.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190606.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190607.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190608.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190609.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190610.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190611.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190612.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190613.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190614.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190615.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190616.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190617.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190618.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190716.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190717.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190718.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190719.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190720.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190721.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190722.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190714.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190715.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190716.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190717.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190718.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190719.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190720.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190714.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190716.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190717.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190718.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190719.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190715.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190716.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190717.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190718.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190719.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190720.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190721.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190715.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190525.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190713.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190714.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190715.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190716.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190717.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190718.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190719.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190720.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190721.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190722.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190714.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190715.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190405.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190503.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190504.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190702.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190721.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190722.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190724.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190725.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190726.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190727.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190728.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190729.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190730.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190731.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190801.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190802.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190612.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190626.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190627.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190628.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190629.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190630.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190701.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190702.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190703.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190704.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190705.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190706.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190707.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190708.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190618.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190619.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190620.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190621.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190622.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190623.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190624.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190703.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190704.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190705.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190703.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190704.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190705.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190625.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190625.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190702.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190710.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190711.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190712.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190713.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190711.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190712.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190713.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190714.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190715.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190716.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190717.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190718.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190719.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190720.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190721.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190722.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190724.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190725.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190726.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190727.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190728.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190729.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190730.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190506.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190504.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190505.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190506.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190507.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190508.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190509.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190224.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191025.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190723.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190917.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191026.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190920.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190921.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190926.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190927.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190928.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190929.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190930.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191001.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191002.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191003.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191004.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191005.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191006.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191007.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191008.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191009.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191010.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191011.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191012.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191013.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191014.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191015.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191016.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191017.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191018.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191019.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191020.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191021.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191022.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191023.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191024.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191025.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191026.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191027.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191028.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191029.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191030.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191031.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191101.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191102.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191103.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191104.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191105.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191106.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191107.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191027.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191028.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190904.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190827.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190901.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190902.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190904.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191028.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191024.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191025.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191026.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191027.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191028.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191029.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191030.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191031.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191029.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190729.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190730.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190731.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190801.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190802.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190827.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190901.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190902.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190720.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190724.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190906.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190907.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190908.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190909.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190721.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190906.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190907.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190908.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190724.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190724.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190725.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191007.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191008.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190724.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190724.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190725.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190726.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190608.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190725.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190726.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190727.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190728.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190729.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190730.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190731.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190801.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190802.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190827.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190901.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190902.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190904.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190725.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190217.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190218.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190729.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190730.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190731.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190801.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190802.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190609.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190610.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190611.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190612.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190613.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190614.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190615.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190616.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190617.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190618.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190619.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190620.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190621.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190622.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190623.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190624.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190625.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190626.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190627.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190628.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190629.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190630.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190701.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190702.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190703.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190704.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190705.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190706.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190707.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190708.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190709.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190710.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190711.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191010.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191010.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191011.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191012.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191013.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191014.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191015.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191016.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191017.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191018.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191019.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191020.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191021.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191022.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191023.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191024.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191025.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191026.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191027.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190908.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190907.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190908.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190915.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190916.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190917.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190918.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190919.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190920.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190921.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190922.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190923.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190924.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190925.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190926.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190927.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190928.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190929.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190930.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191001.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191002.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191003.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191004.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191005.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191006.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191007.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191008.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191009.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191010.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191011.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191012.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191013.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190904.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190906.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190906.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190908.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190728.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190729.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190730.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190727.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190728.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190729.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190730.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190731.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190801.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190802.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190827.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190901.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190902.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190904.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190906.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190907.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190906.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190907.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190906.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190907.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190908.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190909.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190910.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190911.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190912.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190913.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190914.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190915.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190802.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190802.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190611.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190611.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190612.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190315.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190316.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190317.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190318.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191007.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191008.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191009.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191010.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191011.nc4
# ...
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190718.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190710.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190901.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190902.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190904.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190906.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190907.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190908.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190909.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190910.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190911.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190912.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190913.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190914.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190915.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190916.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190802.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190803.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190804.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190827.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190901.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190902.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191002.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20191027.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190915.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190916.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190915.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190805.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190808.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190809.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190810.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190827.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190909.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190909.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190910.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190811.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190901.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190902.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190904.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190816.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190817.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190825.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190826.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190827.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190807.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190806.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190813.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190814.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190815.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190812.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190828.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190829.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190830.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190831.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190901.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190902.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190903.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190904.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190905.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190818.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190819.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190820.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190821.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190822.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190823.nc4
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190824.nc4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0570f511f97c> in <module>
#      60
#      61                     #find the intersection
# ---> 62                     overlaps = calculate_overlaps(LAT, LON, fire_features['geometry'][ii])
#      63                     variable_weighted = np.multiply(variable,overlaps)
#      64                     #save it to the dataframe
#
# <ipython-input-5-3bea930637e7> in calculate_overlaps(LAT, LON, fire_shape)
#      20             NW_lon = LON[ii,jj] + (LON[ii-1,jj-1] - LON[ii,jj])/2
#      21             NE_lat = LAT[ii,jj] + (LAT[ii,jj] - LAT[ii-1,jj-1])/2
# ---> 22             NE_lon = LON[ii,jj] + (LON[ii,jj] - LON[ii-1,jj-1])/2
#      23             poly_cell = Polygon([(NW_lon,NW_lat), (NE_lon,NE_lat), (SE_lon,SE_lat), (SW_lon, SW_lat)])
#      24             overlap_cell = fire_shape.intersection(poly_cell)
#
# ~/anaconda3/envs/ML_py/lib/python3.7/site-packages/numpy/ma/core.py in __getitem__(self, indx)
#    3208             # attempt to apply the heuristic to avoid constructing a full mask
#    3209             mout = nomask
# -> 3210             scalar_expected = _scalar_heuristic(self.data, dout)
#    3211             if scalar_expected is None:
#    3212                 # heuristics have failed
#
# ~/anaconda3/envs/ML_py/lib/python3.7/site-packages/numpy/ma/core.py in _scalar_heuristic(arr, elem)
#    3182             """
#    3183             # obviously a scalar
# -> 3184             if not isinstance(elem, np.ndarray):
#    3185                 return True
#    3186
#
# KeyboardInterrupt:

# %%
# dictionaries that track the variables, dimensions, times and levels
varis = {'/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.*.nc4':['TLML', 'QLML', 'SPEEDLML', 'PS'], 
        '/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.*.nc4': ['T', 'QV'],
         '/static_maps/static_map_1km.nc4': ['fccs', 'slp', 'asp'],
        '/QFED/WESTUS_qfed2.emis_pm25.006.*.nc4':['biomass']}

#0=lat, 1=lon, 2=time, 3=level 
dims = {'/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.*.nc4':['lat', 'lon', 'time'], 
       '/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.*.nc4':['lat', 'lon', 'time', 'lev'],
        '/static_maps/static_map_1km.nc4': ['lat', 'lon'],
       '/QFED/WESTUS_qfed2.emis_pm25.006.*.nc4':['lat', 'lon', 'time']}

times = {'TLML':12, 'QLML':12, 'SPEEDLML':12, 'PS':12, 'T':12, 'QV':12, 'biomass':12}
levels = {'T':[500, 700], 'QV':[700]} 
file_suffix = '.nc4'

#pre-allocate the data frame
num_days = len(fire_attributes)
fire_features = gpd.GeoDataFrame({'Incident Number': np.nan*np.zeros(num_days), 'Fire Name': np.nan*np.zeros(num_days), 
                             'Current Day': np.nan*np.zeros(num_days), 'Lat Fire': np.nan*np.zeros(num_days), 
                             'Lon Fire': np.nan*np.zeros(num_days), 'Number of VIIRS points': np.nan*np.zeros(num_days),
                            'TLML_12Z': np.nan*np.zeros(num_days), 'QLML_12Z': np.nan*np.zeros(num_days),
                            'SPEEDLML_12Z': np.nan*np.zeros(num_days),'PS_12Z': np.nan*np.zeros(num_days),
                            'T_12Z_700mb': np.nan*np.zeros(num_days),'T_12Z_500mb': np.nan*np.zeros(num_days),
                            'QV_12Z_700mb': np.nan*np.zeros(num_days), 'fccs': np.nan*np.zeros(num_days),
                            'slp':np.nan*np.zeros(num_days), 'asp':np.nan*np.zeros(num_days),
                            'biomass_12Z': np.nan*np.zeros(num_days),'geometry': np.nan*np.zeros(num_days)}) # pre-allocate the dataframe
#'fccs': np.nan*np.zeros(num_days),'slp': np.nan*np.zeros(num_days),'asp': np.nan*np.zeros(num_days), 
fire_features['Incident Number'] = fire_attributes['Incident Number'].values
fire_features['Fire Name'] = fire_attributes['Fire Name'].values
fire_features['Current Day'] = fire_attributes['Current Day'].values
fire_features['Lat Fire'] = fire_attributes['Lat Fire'].values
fire_features['Lon Fire'] = fire_attributes['Lon Fire'].values
fire_features['Number of VIIRS points'] = fire_attributes['Number of VIIRS points'].values
fire_features['geometry'] = fire_polygons['geometry'].values

#print(fire_features)
unique_days = np.unique(fire_features['Current Day'].values)
print(len(unique_days))
for dd in range(len(unique_days)):

    date=unique_days[dd]
    yr = date[0:4]
    mo = date[5:7]
    dy = date[8:10]
    print(yr, mo,dy)
    #find the polygons for the given day

    for i in varis : #loop over the file names
        #get the path to the file
        path = '/data2/lthapa/'+yr+i
        if '*' in path:
            path = path.replace('*', yr+mo+dy)
        if np.datetime64(date)>=np.datetime64('2020-09-01') and np.datetime64(date)<=np.datetime64('2020-09-30'):
            path = path.replace('400', '401')
            
        #load the file in as a netcdf dataset
        print(path)
        dat = nc.Dataset(path)
        ndims = len(dims[i])
        if ndims ==2: #lat and lon
            lat = dat[dims[i][0]][:]
            lon = dat[dims[i][1]][:]
        elif ndims == 3: #lat, lon, and time
            lat = dat[dims[i][0]][:]
            lon = dat[dims[i][1]][:]
            t = dat[dims[i][2]][:]
        elif ndims ==4: #lat,lon,time,and level
            lat = dat[dims[i][0]][:]
            lon = dat[dims[i][1]][:]
            t = dat[dims[i][2]][:]
            lev = dat[dims[i][3]][:]
        if len(lat.shape)==1:
            lon, lat = np.meshgrid(lon, lat)
            
        #calculate the areas of the lat/lon grid for the DATASET
        lat_corners, lon_corners = calculate_grid_cell_corners(lat, lon)
        inds = np.where(fire_features['Current Day']==date)[0]
        polys = fire_features['geometry'].iloc[inds].values
        
        for p in range(len(inds)):
            tic = time.time()
            #add a halo to the polygon
            poly = polys[p]
            poly_buff = poly.buffer(1)
            # get the bounds of the buffered polygon
            w,s,e,n = poly_buff.bounds
            #print(w,s,e,n)
            s_ind = np.unique(np.argmin(np.abs(lat-s), axis=0))[0]
            n_ind = np.unique(np.argmin(np.abs(lat-n), axis=0))[0]
            w_ind = np.unique(np.argmin(np.abs(lon-w), axis=1))[0]
            e_ind = np.unique(np.argmin(np.abs(lon-e), axis=1))[0]
            #print(w_ind,s_ind,e_ind,n_ind)
            #lat_sub_inds, lon_sub_inds = np.where((lat>=s)&(lat<=n)&(lon>=w)&(lon<=e))
            #print(lat_sub_inds, lon_sub_inds)
            #remove indices = 0, lat.shape[0], and lat.shape[1]
            lastrow = lat.shape[0]-1
            lastcol = lat.shape[1]-1
        
            #print(lastrow, lastcol)
            

           # print(lat_sub_inds, lon_sub_inds)
    
            
            #tic = time.time()
            overlaps = calculate_overlaps(lat,lon,lat_corners,lon_corners,s_ind,n_ind,w_ind,e_ind, poly) #calculate the overlap between the poly and the lat/lon grid
            print(np.where(overlaps!=0))
            #toc = time.time()
            #print('Time elapsed for calculating overlaps for polygon:', toc-tic)
            for j in varis[i]: #loop over the variable names, which are lists
                var = dat[j][:]
                #print('the dimensions of', j, 'are', var.shape, 'and', j, 'has', ndims, 'dimensions')
                #select the times and levels we need
                if ndims ==2: #lat and lon
                    # calculate overlap
                    #print(var.shape)
                    var_weighted = np.multiply(var,overlaps)
                    var_ave = np.nansum(var_weighted)
                    name_in_table = j
                    fire_features.loc[inds[p],name_in_table] = var_ave
                    
                elif ndims == 3: #lat, lon, and time
                    #select the needed times (12Z)
                    if j in times.keys():
                        ind_time = np.argmin(np.abs(times[j]*60-t))
                        #filter the variable by time
                        var = var[ind_time, :, :]
                        #print(var.shape)
                        var_weighted = np.multiply(var,overlaps)
                        var_ave = np.nansum(var_weighted)
                        name_in_table = j+'_'+str(times[j])+'Z'
                        fire_features.loc[inds[p],name_in_table] = var_ave

                elif ndims ==4: #lat,lon,time,and level
                    #select the needed times and levels
                    if j in times.keys():
                        ind_time = np.argmin(np.abs(times[j]*60-t))
                        #filter the variable by time
                        var = var[ind_time, :, :, :]
                        #filter by levels
                        if j in levels.keys(): #if there are levels, loop through them
                            for l in levels[j]:
                                ind_lev = np.argmin(np.abs(l-lev))
                                var_weighted = np.multiply(var[ind_lev, :, :], overlaps)
                                var_ave = np.nansum(var_weighted)
                                name_in_table = j+'_'+str(times[j])+'Z_'+str(l)+'mb'
                                fire_features.loc[inds[p],name_in_table] = var_ave
            toc = time.time()
            print('Time to process polygon=',toc-tic)
        dat.close() 
print(inds[p])
fire_features.loc[inds[p],:]
# Out:
# 442
# 2019 02 17
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190217.nc4
# (array([4]), array([17]))
# Time to process polygon= 0.011193990707397461
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190217.nc4
# (array([4]), array([17]))
# Time to process polygon= 0.03892874717712402
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([202, 202, 203, 203, 204, 204, 205, 205, 206, 206, 207]), array([935, 936, 935, 936, 935, 936, 935, 936, 935, 936, 935]))
# Time to process polygon= 2.782203435897827
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190217.nc4
# (array([18]), array([105]))
# Time to process polygon= 0.02783679962158203
# 2019 02 18
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190218.nc4
# (array([4]), array([17]))
# Time to process polygon= 0.01071929931640625
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190218.nc4
# (array([4]), array([17]))
# Time to process polygon= 0.03887629508972168
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([202, 202, 203, 203, 204, 204, 205, 205, 206, 206, 207]), array([935, 936, 935, 936, 935, 936, 935, 936, 935, 936, 935]))
# Time to process polygon= 2.7822046279907227
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190218.nc4
# (array([18]), array([105]))
# Time to process polygon= 0.027805089950561523
# 2019 02 24
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190224.nc4
# (array([19]), array([33]))
# Time to process polygon= 0.010907411575317383
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190224.nc4
# (array([19]), array([33]))
# Time to process polygon= 0.039014339447021484
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1079, 1080, 1081]), array([1827, 1827, 1827]))
# Time to process polygon= 2.7512803077697754
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190224.nc4
# (array([96, 97]), array([205, 205]))
# Time to process polygon= 0.029083251953125
# 2019 03 06
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190306.nc4
# (array([0, 1]), array([23, 23]))
# Time to process polygon= 0.010568618774414062
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190306.nc4
# (array([0, 1]), array([23, 23]))
# Time to process polygon= 0.0386357307434082
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([ 0,  0, 36, 36, 37]), array([1268, 1269, 1268, 1269, 1268]))
# Time to process polygon= 2.0193777084350586
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190306.nc4
# (array([0, 3]), array([142, 142]))
# Time to process polygon= 0.02034783363342285
# 2019 03 13
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190313.nc4
# (array([ 9, 10]), array([37, 37]))
# Time to process polygon= 0.01069331169128418
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190313.nc4
# (array([ 9, 10]), array([37, 37]))
# Time to process polygon= 0.038823604583740234
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([526, 527, 527, 527, 527, 528, 528, 528, 528, 528, 528, 529, 529,
#        529, 529, 529, 530, 530, 530, 530, 530, 531, 531, 531, 531, 532,
#        532]), array([2074, 2074, 2075, 2076, 2077, 2074, 2075, 2076, 2077, 2078, 2079,
#        2075, 2076, 2077, 2078, 2079, 2076, 2077, 2078, 2079, 2080, 2077,
#        2078, 2079, 2080, 2079, 2080]))
# Time to process polygon= 2.387390375137329
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190313.nc4
# (array([47, 47]), array([233, 234]))
# Time to process polygon= 0.024046897888183594
# 2019 03 15
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190315.nc4
# (array([5]), array([14]))
# Time to process polygon= 0.010748147964477539
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190315.nc4
# (array([5]), array([14]))
# Time to process polygon= 0.03888964653015137
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([282, 282, 282, 283, 283]), array([791, 792, 793, 791, 792]))
# Time to process polygon= 2.770280361175537
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190315.nc4
# (array([25]), array([89]))
# Time to process polygon= 0.027990341186523438
# 2019 03 16
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190316.nc4
# (array([5]), array([14]))
# Time to process polygon= 0.010680198669433594
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190316.nc4
# (array([5]), array([14]))
# Time to process polygon= 0.03841280937194824
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([281, 281, 282, 282]), array([791, 792, 791, 792]))
# Time to process polygon= 2.758998155593872
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190316.nc4
# (array([25]), array([89]))
# Time to process polygon= 0.028116226196289062
# 2019 03 17
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190317.nc4
# (array([5]), array([14]))
# Time to process polygon= 0.010701417922973633
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190317.nc4
# (array([5]), array([14]))
# Time to process polygon= 0.03823685646057129
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([281, 282, 282]), array([792, 791, 792]))
# Time to process polygon= 2.738163709640503
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190317.nc4
# (array([25]), array([89]))
# Time to process polygon= 0.027761459350585938
# 2019 03 18
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190318.nc4
# (array([5]), array([14]))
# Time to process polygon= 0.010662555694580078
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190318.nc4
# (array([5]), array([14]))
# Time to process polygon= 0.038317203521728516
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([281, 282, 282]), array([792, 791, 792]))
# Time to process polygon= 2.9507906436920166
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190318.nc4
# (array([25]), array([89]))
# Time to process polygon= 0.030646085739135742
# 2019 04 05
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190405.nc4
# (array([23]), array([34]))
# Time to process polygon= 0.011397600173950195
# (array([14]), array([35]))
# Time to process polygon= 0.0075092315673828125
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190405.nc4
# (array([23]), array([34]))
# Time to process polygon= 0.03860878944396973
# (array([14]), array([35]))
# Time to process polygon= 0.013529539108276367
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1256, 1256]), array([1884, 1885]))
# Time to process polygon= 2.968308925628662
# (array([786, 786, 786, 787, 787, 787, 788, 788]), array([1937, 1938, 1939, 1937, 1938, 1939, 1937, 1938]))
# Time to process polygon= 2.9697325229644775
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190405.nc4
# (array([112]), array([212]))
# Time to process polygon= 0.030481815338134766
# (array([70]), array([218]))
# Time to process polygon= 0.02693009376525879
# 2019 04 08
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190408.nc4
# (array([6]), array([20]))
# Time to process polygon= 0.010975837707519531
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190408.nc4
# (array([6]), array([20]))
# Time to process polygon= 0.03863859176635742
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([309, 309, 310]), array([1086, 1087, 1086]))
# Time to process polygon= 2.9650368690490723
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190408.nc4
# (array([27]), array([122]))
# Time to process polygon= 0.03017568588256836
# 2019 04 19
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190419.nc4
# (array([31]), array([17]))
# Time to process polygon= 0.011146068572998047
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190419.nc4
# (array([31]), array([17]))
# Time to process polygon= 0.038575172424316406
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1731, 1732]), array([967, 967]))
# Time to process polygon= 2.9656152725219727
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190419.nc4
# (array([155]), array([109]))
# Time to process polygon= 0.030652284622192383
# 2019 04 27
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190427.nc4
# (array([6]), array([20]))
# Time to process polygon= 0.011179924011230469
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190427.nc4
# (array([6]), array([20]))
# Time to process polygon= 0.038304805755615234
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([307, 308, 308, 309, 309]), array([1088, 1088, 1089, 1088, 1089]))
# Time to process polygon= 2.998851776123047
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190427.nc4
# (array([27]), array([122]))
# Time to process polygon= 0.030521631240844727
# 2019 05 01
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190501.nc4
# (array([23]), array([5]))
# Time to process polygon= 0.011146783828735352
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190501.nc4
# (array([23]), array([5]))
# Time to process polygon= 0.03864264488220215
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1294, 1294, 1295, 1295]), array([284, 285, 284, 285]))
# Time to process polygon= 2.976022481918335
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190501.nc4
# (array([116]), array([32]))
# Time to process polygon= 0.03059554100036621
# 2019 05 02
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190502.nc4
# (array([23]), array([5]))
# Time to process polygon= 0.011180877685546875
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190502.nc4
# (array([23]), array([5]))
# Time to process polygon= 0.03844118118286133
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1294, 1295]), array([285, 285]))
# Time to process polygon= 2.9631588459014893
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190502.nc4
# (array([116]), array([32]))
# Time to process polygon= 0.036041259765625
# 2019 05 03
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190503.nc4
# (array([7]), array([23]))
# Time to process polygon= 0.01130056381225586
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190503.nc4
# (array([7]), array([23]))
# Time to process polygon= 0.03851151466369629
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([374]), array([1272]))
# Time to process polygon= 2.951207160949707
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190503.nc4
# (array([33]), array([143]))
# Time to process polygon= 0.035752296447753906
# 2019 05 04
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190504.nc4
# (array([7]), array([23]))
# Time to process polygon= 0.011357307434082031
# (array([23]), array([4]))
# Time to process polygon= 0.007555484771728516
# (array([23]), array([4]))
# Time to process polygon= 0.007497072219848633
# (array([11]), array([19]))
# Time to process polygon= 0.007604122161865234
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190504.nc4
# (array([7]), array([23]))
# Time to process polygon= 0.0381011962890625
# (array([23]), array([4]))
# Time to process polygon= 0.013470888137817383
# (array([23]), array([4]))
# Time to process polygon= 0.013269662857055664
# (array([11]), array([19]))
# Time to process polygon= 0.013397932052612305
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([373, 373, 373, 374, 374, 374, 375]), array([1271, 1272, 1273, 1271, 1272, 1273, 1271]))
# Time to process polygon= 3.0139293670654297
# (array([1298, 1298, 1299, 1299]), array([222, 223, 222, 223]))
# Time to process polygon= 2.9355034828186035
# (array([1298, 1298, 1299, 1299]), array([222, 223, 222, 223]))
# Time to process polygon= 2.9960858821868896
# (array([591, 591, 592, 592, 592, 593, 593, 593, 594, 594]), array([1049, 1050, 1049, 1050, 1051, 1049, 1050, 1051, 1049, 1050]))
# Time to process polygon= 3.0577056407928467
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190504.nc4
# (array([33]), array([143]))
# Time to process polygon= 0.03564310073852539
# (array([116]), array([25]))
# Time to process polygon= 0.026880264282226562
# (array([116]), array([25]))
# Time to process polygon= 0.026581525802612305
# (array([53]), array([118]))
# Time to process polygon= 0.028676509857177734
# 2019 05 05
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190505.nc4
# (array([23]), array([4]))
# Time to process polygon= 0.01117849349975586
# (array([23]), array([4]))
# Time to process polygon= 0.007403373718261719
# (array([11]), array([19]))
# Time to process polygon= 0.007546424865722656
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190505.nc4
# (array([23]), array([4]))
# Time to process polygon= 0.037894487380981445
# (array([23]), array([4]))
# Time to process polygon= 0.013564348220825195
# (array([11]), array([19]))
# Time to process polygon= 0.013392925262451172
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1298, 1298, 1299, 1299, 1299, 1300, 1300]), array([222, 223, 222, 223, 224, 222, 223]))
# Time to process polygon= 2.9728331565856934
# (array([1298, 1298, 1299, 1299, 1299, 1300, 1300]), array([222, 223, 222, 223, 224, 222, 223]))
# Time to process polygon= 2.916262149810791
# (array([591, 591, 592, 592, 592, 593, 593, 593, 594, 594]), array([1049, 1050, 1049, 1050, 1051, 1049, 1050, 1051, 1049, 1050]))
# Time to process polygon= 3.121906280517578
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190505.nc4
# (array([116]), array([25]))
# Time to process polygon= 0.03579092025756836
# (array([116]), array([25]))
# Time to process polygon= 0.02690577507019043
# (array([53]), array([118]))
# Time to process polygon= 0.02848672866821289
# 2019 05 06
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190506.nc4
# (array([6]), array([20]))
# Time to process polygon= 0.01090693473815918
# (array([23]), array([4]))
# Time to process polygon= 0.007462501525878906
# (array([32]), array([13]))
# Time to process polygon= 0.007142782211303711
# (array([23]), array([4]))
# Time to process polygon= 0.007398843765258789
# (array([11]), array([19]))
# Time to process polygon= 0.0074808597564697266
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190506.nc4
# (array([6]), array([20]))
# Time to process polygon= 0.03764677047729492
# (array([23]), array([4]))
# Time to process polygon= 0.01386713981628418
# (array([32]), array([13]))
# Time to process polygon= 0.012924671173095703
# (array([23]), array([4]))
# Time to process polygon= 0.013279914855957031
# (array([11]), array([19]))
# Time to process polygon= 0.013434171676635742
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([346, 347]), array([1116, 1116]))
# Time to process polygon= 2.9616763591766357
# (array([1298, 1298, 1299, 1299, 1299, 1300, 1300]), array([222, 223, 222, 223, 224, 222, 223]))
# Time to process polygon= 2.917262554168701
# (array([1785, 1786, 1786]), array([732, 731, 732]))
# Time to process polygon= 2.9948673248291016
# (array([1298, 1298, 1299, 1299, 1299, 1300, 1300]), array([222, 223, 222, 223, 224, 222, 223]))
# Time to process polygon= 2.9166860580444336
# (array([591, 591, 592, 592, 592, 593, 593, 593, 594, 594]), array([1049, 1050, 1049, 1050, 1051, 1049, 1050, 1051, 1049, 1050]))
# Time to process polygon= 3.1343207359313965
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190506.nc4
# (array([31]), array([125]))
# Time to process polygon= 0.03640627861022949
# (array([116]), array([25]))
# Time to process polygon= 0.02702641487121582
# (array([160]), array([82]))
# Time to process polygon= 0.026414871215820312
# (array([116]), array([25]))
# Time to process polygon= 0.026456832885742188
# (array([53]), array([118]))
# Time to process polygon= 0.02860283851623535
# 2019 05 07
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190507.nc4
# (array([23]), array([4]))
# Time to process polygon= 0.011523962020874023
# (array([32]), array([13]))
# Time to process polygon= 0.007117748260498047
# (array([11]), array([19]))
# Time to process polygon= 0.007359981536865234
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190507.nc4
# (array([23]), array([4]))
# Time to process polygon= 0.04167509078979492
# (array([32]), array([13]))
# Time to process polygon= 0.013139724731445312
# (array([11]), array([19]))
# Time to process polygon= 0.013248205184936523
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1298, 1298, 1299, 1299, 1299, 1300, 1300]), array([222, 223, 222, 223, 224, 222, 223]))
# Time to process polygon= 2.962902307510376
# (array([1785, 1785, 1786]), array([732, 733, 732]))
# Time to process polygon= 2.934605836868286
# (array([592, 592, 593]), array([1049, 1050, 1050]))
# Time to process polygon= 2.97953200340271
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190507.nc4
# (array([116]), array([25]))
# Time to process polygon= 0.035880327224731445
# (array([160]), array([82]))
# Time to process polygon= 0.026681184768676758
# (array([53]), array([118]))
# Time to process polygon= 0.02648138999938965
# 2019 05 08
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190508.nc4
# (array([23]), array([4]))
# Time to process polygon= 0.011257171630859375
# (array([32]), array([13]))
# Time to process polygon= 0.007303714752197266
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190508.nc4
# (array([23]), array([4]))
# Time to process polygon= 0.0382082462310791
# (array([32]), array([13]))
# Time to process polygon= 0.013324499130249023
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1298, 1298, 1299, 1299, 1299, 1300, 1300]), array([222, 223, 222, 223, 224, 222, 223]))
# Time to process polygon= 2.968374252319336
# (array([1785, 1785, 1786]), array([732, 733, 732]))
# Time to process polygon= 2.943058967590332
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190508.nc4
# (array([116]), array([25]))
# Time to process polygon= 0.035538673400878906
# (array([160]), array([82]))
# Time to process polygon= 0.026918888092041016
# 2019 05 09
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190509.nc4
# (array([23]), array([4]))
# Time to process polygon= 0.011332273483276367
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190509.nc4
# (array([23]), array([4]))
# Time to process polygon= 0.038439273834228516
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([1298, 1299, 1299]), array([222, 222, 223]))
# Time to process polygon= 2.996182441711426
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190509.nc4
# (array([116]), array([25]))
# Time to process polygon= 0.03561043739318848
# 2019 05 14
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190514.nc4
# (array([4]), array([32]))
# Time to process polygon= 0.011124849319458008
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190514.nc4
# (array([4]), array([32]))
# Time to process polygon= 0.03745532035827637
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([243, 244, 244]), array([1756, 1755, 1756]))
# Time to process polygon= 2.9692680835723877
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190514.nc4
# (array([21, 22]), array([197, 197]))
# Time to process polygon= 0.03702116012573242
# 2019 05 16
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190516.nc4
# (array([5]), array([25]))
# Time to process polygon= 0.011153697967529297
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190516.nc4
# (array([5]), array([25]))
# Time to process polygon= 0.03768730163574219
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([288, 288, 289, 289]), array([1371, 1372, 1371, 1372]))
# Time to process polygon= 2.9667320251464844
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190516.nc4
# (array([26]), array([154]))
# Time to process polygon= 0.035746097564697266
# 2019 05 17
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190517.nc4
# (array([5]), array([25]))
# Time to process polygon= 0.011041402816772461
# (array([5]), array([33]))
# Time to process polygon= 0.007598161697387695
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190517.nc4
# (array([5]), array([25]))
# Time to process polygon= 0.03795671463012695
# (array([5]), array([33]))
# Time to process polygon= 0.013430118560791016
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([288, 288, 289, 289, 289]), array([1371, 1372, 1370, 1371, 1372]))
# Time to process polygon= 2.978989839553833
# (array([257, 258, 258, 259, 259]), array([1832, 1832, 1833, 1832, 1833]))
# Time to process polygon= 2.9396631717681885
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190517.nc4
# (array([25, 26]), array([154, 154]))
# Time to process polygon= 0.03671979904174805
# (array([23]), array([206]))
# Time to process polygon= 0.02682948112487793
# 2019 05 19
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190519.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.011181354522705078
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190519.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03772330284118652
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([477, 478, 478, 478, 479, 479, 479, 480]), array([1206, 1205, 1206, 1207, 1205, 1206, 1207, 1206]))
# Time to process polygon= 3.1146137714385986
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190519.nc4
# (array([42, 43, 43]), array([135, 135, 136]))
# Time to process polygon= 0.03824043273925781
# 2019 05 20
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190520.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.011110305786132812
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190520.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.037789344787597656
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([477, 478, 478, 478, 479, 479, 479, 480]), array([1206, 1205, 1206, 1207, 1205, 1206, 1207, 1206]))
# Time to process polygon= 3.117969274520874
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190520.nc4
# (array([42, 43, 43]), array([135, 135, 136]))
# Time to process polygon= 0.038680076599121094
# 2019 05 21
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190521.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.011148929595947266
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190521.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03782343864440918
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([477, 478, 478, 478, 479, 479, 479, 480]), array([1206, 1205, 1206, 1207, 1205, 1206, 1207, 1206]))
# Time to process polygon= 3.099374532699585
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190521.nc4
# (array([42, 43, 43]), array([135, 135, 136]))
# Time to process polygon= 0.03831076622009277
# 2019 05 22
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190522.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.011136770248413086
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190522.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03742051124572754
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([477, 478, 478, 478, 479, 479, 479, 480]), array([1206, 1205, 1206, 1207, 1205, 1206, 1207, 1206]))
# Time to process polygon= 3.101614236831665
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190522.nc4
# (array([42, 43, 43]), array([135, 135, 136]))
# Time to process polygon= 0.038301944732666016
# 2019 05 23
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190523.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.01120758056640625
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190523.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.037589073181152344
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([477, 478, 478, 478, 479, 479, 479, 480]), array([1206, 1205, 1206, 1207, 1205, 1206, 1207, 1206]))
# Time to process polygon= 3.106377363204956
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190523.nc4
# (array([42, 43, 43]), array([135, 135, 136]))
# Time to process polygon= 0.038237571716308594
# 2019 05 24
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190524.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.01100778579711914
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190524.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03750801086425781
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([478, 479]), array([1206, 1206]))
# Time to process polygon= 2.969243049621582
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190524.nc4
# (array([43]), array([135]))
# Time to process polygon= 0.035852670669555664
# 2019 05 25
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190525.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.01116490364074707
# (array([6]), array([20]))
# Time to process polygon= 0.00762486457824707
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190525.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03745722770690918
# (array([6]), array([20]))
# Time to process polygon= 0.013484477996826172
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([478, 479]), array([1207, 1207]))
# Time to process polygon= 2.9579238891601562
# (array([308, 309, 309, 310, 310, 311, 311]), array([1115, 1114, 1115, 1114, 1115, 1114, 1115]))
# Time to process polygon= 2.9595086574554443
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190525.nc4
# (array([43]), array([136]))
# Time to process polygon= 0.03596854209899902
# (array([27, 28]), array([125, 125]))
# Time to process polygon= 0.0285799503326416
# 2019 05 26
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190526.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.011544942855834961
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190526.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.041169166564941406
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([478, 479]), array([1207, 1207]))
# Time to process polygon= 2.9633078575134277
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190526.nc4
# (array([43]), array([136]))
# Time to process polygon= 0.03577566146850586
# 2019 05 27
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190527.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.011104345321655273
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190527.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03767585754394531
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([478, 479]), array([1207, 1207]))
# Time to process polygon= 2.7112481594085693
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190527.nc4
# (array([43]), array([136]))
# Time to process polygon= 0.03340864181518555
# 2019 05 28
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190528.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.010660409927368164
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190528.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.036855220794677734
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([478, 479]), array([1207, 1207]))
# Time to process polygon= 2.713918447494507
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190528.nc4
# (array([43]), array([136]))
# Time to process polygon= 0.033211469650268555
# 2019 05 29
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190529.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.010685443878173828
# (array([5]), array([25]))
# Time to process polygon= 0.006997346878051758
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190529.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.036546945571899414
# (array([5]), array([25]))
# Time to process polygon= 0.012992143630981445
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([478, 479, 480, 481, 481, 482]), array([1207, 1207, 1207, 1206, 1207, 1206]))
# Time to process polygon= 2.7548441886901855
# (array([302, 302, 302, 303, 303, 303, 304, 304, 304]), array([1407, 1408, 1409, 1407, 1408, 1409, 1407, 1408, 1409]))
# Time to process polygon= 2.8011624813079834
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190529.nc4
# (array([43, 43]), array([135, 136]))
# Time to process polygon= 0.034075021743774414
# (array([27]), array([158]))
# Time to process polygon= 0.026392459869384766
# 2019 05 30
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190530.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.010464668273925781
# (array([6]), array([20]))
# Time to process polygon= 0.0069310665130615234
# (array([5]), array([25]))
# Time to process polygon= 0.0065767765045166016
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190530.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.036273956298828125
# (array([6]), array([20]))
# Time to process polygon= 0.012895584106445312
# (array([5]), array([25]))
# Time to process polygon= 0.012487649917602539
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([479, 480, 481, 481, 482, 483, 483, 484]), array([1205, 1205, 1204, 1205, 1204, 1203, 1204, 1203]))
# Time to process polygon= 2.7874507904052734
# (array([307, 307, 308, 308, 309, 309, 310, 310]), array([1114, 1115, 1114, 1115, 1114, 1115, 1114, 1115]))
# Time to process polygon= 2.7316935062408447
# (array([302, 303]), array([1408, 1408]))
# Time to process polygon= 2.7443900108337402
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190530.nc4
# (array([43]), array([135]))
# Time to process polygon= 0.0330810546875
# (array([27]), array([125]))
# Time to process polygon= 0.024302959442138672
# (array([27]), array([158]))
# Time to process polygon= 0.023781299591064453
# 2019 05 31
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190531.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.010588884353637695
# (array([7]), array([22]))
# Time to process polygon= 0.006956338882446289
# (array([5]), array([25]))
# Time to process polygon= 0.0066640377044677734
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190531.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03634142875671387
# (array([7]), array([22]))
# Time to process polygon= 0.012917280197143555
# (array([5]), array([25]))
# Time to process polygon= 0.012488365173339844
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([477, 477, 478, 478, 478, 478, 479, 479, 479, 479, 480, 480, 480,
#        481, 481, 482, 482, 482]), array([1205, 1206, 1204, 1205, 1206, 1207, 1204, 1205, 1206, 1207, 1204,
#        1205, 1206, 1204, 1205, 1203, 1204, 1205]))
# Time to process polygon= 2.8025288581848145
# (array([387, 388, 388]), array([1215, 1214, 1215]))
# Time to process polygon= 2.686908483505249
# (array([302, 303]), array([1408, 1408]))
# Time to process polygon= 2.7311320304870605
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190531.nc4
# (array([42, 43, 43]), array([135, 135, 136]))
# Time to process polygon= 0.035616159439086914
# (array([34]), array([136]))
# Time to process polygon= 0.024327516555786133
# (array([27]), array([158]))
# Time to process polygon= 0.024047136306762695
# 2019 06 01
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190601.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.010622501373291016
# (array([7]), array([22]))
# Time to process polygon= 0.006984710693359375
# (array([5]), array([25]))
# Time to process polygon= 0.00659632682800293
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190601.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03644108772277832
# (array([7]), array([22]))
# Time to process polygon= 0.013063192367553711
# (array([5]), array([25]))
# Time to process polygon= 0.012569665908813477
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([477, 478, 478, 478, 478, 478, 479, 479, 479, 479, 479, 479, 480,
#        480, 480, 480, 480, 481, 481, 481, 481, 482, 482, 482, 483, 483,
#        483, 484, 484]), array([1206, 1205, 1206, 1207, 1208, 1209, 1204, 1205, 1206, 1207, 1208,
#        1209, 1204, 1205, 1206, 1207, 1208, 1204, 1205, 1206, 1207, 1204,
#        1205, 1206, 1203, 1204, 1205, 1203, 1204]))
# Time to process polygon= 2.8533267974853516
# (array([388, 388, 388, 389, 389]), array([1214, 1215, 1216, 1215, 1216]))
# Time to process polygon= 2.7070279121398926
# (array([302, 302]), array([1407, 1408]))
# Time to process polygon= 2.737699031829834
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190601.nc4
# (array([43, 43]), array([135, 136]))
# Time to process polygon= 0.03454899787902832
# (array([34, 34, 35, 35]), array([136, 137, 136, 137]))
# Time to process polygon= 0.026797056198120117
# (array([27]), array([158]))
# Time to process polygon= 0.023770570755004883
# 2019 06 02
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190602.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.010607481002807617
# (array([7]), array([22]))
# Time to process polygon= 0.006903886795043945
# (array([5]), array([25]))
# Time to process polygon= 0.006607532501220703
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190602.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.03670620918273926
# (array([7]), array([22]))
# Time to process polygon= 0.012977361679077148
# (array([5]), array([25]))
# Time to process polygon= 0.013022184371948242
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([476, 476, 476, 477, 477, 477, 477, 477, 478, 478, 478, 478, 479,
#        479, 479, 479, 479, 480, 480, 480, 480, 481, 481, 481, 481, 482,
#        482, 482, 482, 483, 483, 483, 484, 484]), array([1206, 1207, 1208, 1205, 1206, 1207, 1208, 1209, 1205, 1206, 1207,
#        1208, 1204, 1205, 1206, 1207, 1208, 1204, 1205, 1206, 1207, 1204,
#        1205, 1206, 1207, 1204, 1205, 1206, 1207, 1204, 1205, 1206, 1204,
#        1205]))
# Time to process polygon= 2.847461223602295
# (array([387, 387, 388, 388, 388, 389, 389]), array([1214, 1215, 1214, 1215, 1216, 1215, 1216]))
# Time to process polygon= 2.72455096244812
# (array([302, 302]), array([1407, 1408]))
# Time to process polygon= 2.733717679977417
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190602.nc4
# (array([42, 42, 43, 43]), array([135, 136, 135, 136]))
# Time to process polygon= 0.03583073616027832
# (array([34, 34, 35, 35]), array([136, 137, 136, 137]))
# Time to process polygon= 0.02687692642211914
# (array([27]), array([158]))
# Time to process polygon= 0.024057388305664062
# 2019 06 03
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190603.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.01047062873840332
# (array([7]), array([22]))
# Time to process polygon= 0.006964445114135742
# (array([5]), array([25]))
# Time to process polygon= 0.0066907405853271484
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190603.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.036849021911621094
# (array([7]), array([22]))
# Time to process polygon= 0.012979507446289062
# (array([5]), array([25]))
# Time to process polygon= 0.012441873550415039
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# (array([474, 474, 475, 475, 475, 476, 476, 476, 476, 476, 477, 477, 477,
#        477, 477, 478, 478, 478, 478, 478, 478, 479, 479, 479, 479, 479,
#        480, 480, 480, 480, 481, 481, 481, 481, 482, 482, 482, 482, 483,
#        483]), array([1206, 1207, 1206, 1207, 1208, 1205, 1206, 1207, 1208, 1209, 1205,
#        1206, 1207, 1208, 1209, 1205, 1206, 1207, 1208, 1209, 1210, 1205,
#        1206, 1207, 1208, 1209, 1205, 1206, 1207, 1208, 1204, 1205, 1206,
#        1207, 1204, 1205, 1206, 1207, 1204, 1205]))
# Time to process polygon= 2.8844804763793945
# (array([387, 387, 388, 388, 388, 389, 389, 389, 390, 390, 390, 391, 391,
#        391, 391, 392]), array([1214, 1215, 1214, 1215, 1216, 1214, 1215, 1216, 1214, 1215, 1216,
#        1214, 1215, 1216, 1217, 1217]))
# Time to process polygon= 2.7345311641693115
# (array([301, 302, 302]), array([1408, 1407, 1408]))
# Time to process polygon= 2.7444801330566406
# /data2/lthapa/2019/QFED/WESTUS_qfed2.emis_pm25.006.20190603.nc4
# (array([42, 42, 43, 43]), array([135, 136, 135, 136]))
# Time to process polygon= 0.03633546829223633
# (array([34, 34, 35, 35]), array([136, 137, 136, 137]))
# Time to process polygon= 0.026984691619873047
# (array([27]), array([158]))
# Time to process polygon= 0.024144411087036133
# 2019 06 04
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst1_2d_lfo_Nx.20190604.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.011023759841918945
# (array([7]), array([22]))
# Time to process polygon= 0.006978273391723633
# (array([5]), array([25]))
# Time to process polygon= 0.0066373348236083984
# (array([32]), array([8]))
# Time to process polygon= 0.0069310665130615234
# /data2/lthapa/2019/MERRA2/WESTUS_MERRA2_400.inst3_3d_asm_Np.20190604.nc4
# (array([9]), array([22]))
# Time to process polygon= 0.04043292999267578
# (array([7]), array([22]))
# Time to process polygon= 0.013038158416748047
# (array([5]), array([25]))
# Time to process polygon= 0.012646913528442383
# (array([32]), array([8]))
# Time to process polygon= 0.012743234634399414
# /data2/lthapa/2019/static_maps/static_map_1km.nc4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-0300fe7f6edd> in <module>
#     105
#     106             #tic = time.time()
# --> 107             overlaps = calculate_overlaps(lat,lon,lat_corners,lon_corners,s_ind,n_ind,w_ind,e_ind, poly) #calculate the overlap between the poly and the lat/lon grid
#     108             print(np.where(overlaps!=0))
#     109             #toc = time.time()
#
# <ipython-input-88-8f26c0b6a187> in calculate_overlaps(lat, lon, lat_corners, lon_corners, lat_start, lat_stop, lon_start, lon_stop, fire_shape)
#      20             NE_lon = lon_corners[ii, jj]"""
#      21             poly_cell = Polygon([(lon_corners[ii, jj-1],lat_corners[ii, jj-1]), (lon_corners[ii, jj],lat_corners[ii, jj]), (lon_corners[ii-1, jj],lat_corners[ii-1, jj-1]), (lon_corners[ii-1, jj-1], lat_corners[ii-1, jj-1])])
# ---> 22             overlap_cell = fire_shape.intersection(poly_cell)
#      23             #overlaps are the fraction of the POLYGON in each grid cell
#      24             overlaps[ii,jj] = overlap_cell.area/fire_shape.area
#
# ~/anaconda3/envs/ML_py/lib/python3.7/site-packages/shapely/geometry/base.py in intersection(self, other)
#     674     def intersection(self, other):
#     675         """Returns the intersection of the geometries"""
# --> 676         return geom_factory(self.impl['intersection'](self, other))
#     677
#     678     def symmetric_difference(self, other):
#
# ~/anaconda3/envs/ML_py/lib/python3.7/site-packages/shapely/geometry/base.py in geom_factory(g, parent)
#      89     ob._geom = g
#      90     ob.__p__ = parent
# ---> 91     if lgeos.methods['has_z'](g):
#      92         ob._ndim = 3
#      93     else:
#
# ~/anaconda3/envs/ML_py/lib/python3.7/site-packages/shapely/geos.py in errcheck_predicate(result, func, argtuple)
#     579
#     580
# --> 581 def errcheck_predicate(result, func, argtuple):
#     582     """Result is 2 on exception, 1 on True, 0 on False"""
#     583     if result == 2:
#
# KeyboardInterrupt:

# %%
fire_features
#therest = fire_features[['Incident Number', 'Fire Name', 'Current Day','Lat Fire', 'Lon Fire','Number of VIIRS points', 'TLML_12Z', 'QLML_12Z','SPEEDLML_12Z','PS_12Z','T_12Z_700mb','T_12Z_500mb','QV_12Z_700mb', 'biomass_12Z']]



#therest.to_csv('fire_features.csv')
# Out:
#       Incident Number      Fire Name Current Day   Lat Fire    Lon Fire  \
# 0          10662684.0  PAINTED WAGON  2019-04-08  33.786944 -112.753333
# 1          10663171.0  LONE MOUNTAIN  2019-06-09  33.808056 -105.738611
# 2          10663171.0  LONE MOUNTAIN  2019-06-10  33.808056 -105.738611
# 3          10663171.0  LONE MOUNTAIN  2019-06-11  33.808056 -105.738611
# 4          10663171.0  LONE MOUNTAIN  2019-06-12  33.808056 -105.738611
# ...               ...            ...         ...        ...         ...
# 8156       11979237.0          Trail  2020-11-02  34.147222 -112.117778
# 8157       11980186.0      SANDERSON  2020-12-13  33.889444 -117.070833
# 8158       11980587.0        CREEK 5  2020-12-24  33.402646 -117.266795
# 8159       11980587.0        CREEK 5  2020-12-25  33.402646 -117.266795
# 8160       11980949.0        CREEK 5  2020-12-24  33.407667 -117.269667
#
#       Number of VIIRS points  TLML_12Z  QLML_12Z  SPEEDLML_12Z  PS_12Z  \
# 0                        3.0       NaN       NaN           NaN     NaN
# 1                        2.0       NaN       NaN           NaN     NaN
# 2                        0.0       NaN       NaN           NaN     NaN
# 3                        0.0       NaN       NaN           NaN     NaN
# 4                        0.0       NaN       NaN           NaN     NaN
# ...                      ...       ...       ...           ...     ...
# 8156                     2.0       NaN       NaN           NaN     NaN
# 8157                    11.0       NaN       NaN           NaN     NaN
# 8158                     2.0       NaN       NaN           NaN     NaN
# 8159                    16.0       NaN       NaN           NaN     NaN
# 8160                     2.0       NaN       NaN           NaN     NaN
#
#       T_12Z_700mb  T_12Z_500mb  QV_12Z_700mb  fccs  slp  asp  biomass_12Z  \
# 0             NaN          NaN           NaN   NaN  NaN  NaN          NaN
# 1             NaN          NaN           NaN   NaN  NaN  NaN          NaN
# 2             NaN          NaN           NaN   NaN  NaN  NaN          NaN
# 3             NaN          NaN           NaN   NaN  NaN  NaN          NaN
# 4             NaN          NaN           NaN   NaN  NaN  NaN          NaN
# ...           ...          ...           ...   ...  ...  ...          ...
# 8156          NaN          NaN           NaN   NaN  NaN  NaN          NaN
# 8157          NaN          NaN           NaN   NaN  NaN  NaN          NaN
# 8158          NaN          NaN           NaN   NaN  NaN  NaN          NaN
# 8159          NaN          NaN           NaN   NaN  NaN  NaN          NaN
# 8160          NaN          NaN           NaN   NaN  NaN  NaN          NaN
#
#                                                geometry
# 0     POLYGON ((-112.75455 33.78632, -112.76012 33.7...
# 1     POLYGON ((-105.73275 33.80235, -105.73861 33.8...
# 2     POLYGON ((-105.73275 33.80235, -105.73861 33.8...
# 3     POLYGON ((-105.73275 33.80235, -105.73861 33.8...
# 4     POLYGON ((-105.73275 33.80235, -105.73861 33.8...
# ...                                                 ...
# 8156  POLYGON ((-112.11669 34.11898, -112.12564 34.1...
# 8157  POLYGON ((-117.03702 33.90632, -117.04484 33.9...
# 8158  POLYGON ((-117.27595 33.37881, -117.27495 33.3...
# 8159  POLYGON ((-117.29549 33.36558, -117.29713 33.4...
# 8160  POLYGON ((-117.27595 33.37881, -117.26967 33.4...
#
# [8161 rows x 18 columns]

# %% [markdown]
# ## Helper Functions

# %%
#this function calculates the area of each grid in a given grid cell
# LAT and LON should be 2d
def calculate_grid_cell_corners(LAT, LON):
    #we will assume the very edges of the polygons don't touch the boundary of the domain
    lat_corners = (LAT[0:(lat.shape[0]-1),  0:(lat.shape[1])-1] + LAT[1:(lat.shape[0]), 1:(lat.shape[1])])/2
    lon_corners = (LON[0:(lat.shape[0]-1),  0:(lat.shape[1])-1] + LON[1:(lat.shape[0]), 1:(lat.shape[1])])/2
    return lat_corners, lon_corners
    """for ii in range(1,LAT.shape[0]-1):
        for jj in range(1, LAT.shape[1]-1):
            cell_lat = LAT[ii, jj]
            cell_lon = LON[ii, jj]
            SW_lat[ii,jj] = LAT[ii,jj] + (LAT[ii-1,jj-1] - LAT[ii,jj])/2
            SW_lon[ii,jj] = LON[ii,jj] + (LON[ii-1,jj-1] - LON[ii,jj])/2
            SE_lat[ii,jj] = LAT[ii,jj] + (LAT[ii-1,jj-1] - LAT[ii,jj])/2
            SE_lon[ii,jj] = LON[ii,jj] + (LON[ii,jj] - LON[ii-1,jj-1])/2
            NW_lat[ii,jj] = LAT[ii,jj] + (LAT[ii,jj] - LAT[ii-1,jj-1])/2
            NW_lon[ii,jj] = LON[ii,jj] + (LON[ii-1,jj-1] - LON[ii,jj])/2
            NE_lat[ii,jj] = LAT[ii,jj] + (LAT[ii,jj] - LAT[ii-1,jj-1])/2
            NE_lon[ii,jj] = LON[ii,jj] + (LON[ii,jj] - LON[ii-1,jj-1])/2
    return  SW_lat, SW_lon, SE_lat, SE_lon, NW_lat, NW_lon, NE_lat, NE_lon"""

# %%
# this function calculates the overlap between the given shape (fire_shape) and given grid (LAT, LON). 
#LAT and LON should be 2D

def calculate_overlaps(lat, lon, lat_corners, lon_corners, lat_start, lat_stop, lon_start, lon_stop, fire_shape):
    overlaps = np.zeros(lat.shape)
    # buffer the fire shape so it has a non zero area
    if fire_shape.area ==0:
        fire_shape = fire_shape.buffer(0.01)
    # find the intersection between the first day's polygon and the  grid
    for ii in range(lat_start, lat_stop):
        for jj in range(lon_start, lon_stop):
            #print('ctr', lat[ii,jj], lon[ii,jj])
            """ SW_lat = lat_corners[ii-1, jj-1]
            SW_lon = lon_corners[ii-1, jj-1]
            SE_lat = lat_corners[ii-1, jj-1]
            SE_lon = lon_corners[ii-1, jj]
            NW_lat = lat_corners[ii, jj-1]
            NW_lon = lon_corners[ii, jj-1]
            NE_lat = lat_corners[ii, jj]
            NE_lon = lon_corners[ii, jj]"""
            poly_cell = Polygon([(lon_corners[ii, jj-1],lat_corners[ii, jj-1]), (lon_corners[ii, jj],lat_corners[ii, jj]), (lon_corners[ii-1, jj],lat_corners[ii-1, jj-1]), (lon_corners[ii-1, jj-1], lat_corners[ii-1, jj-1])])
            overlap_cell = fire_shape.intersection(poly_cell)
            #overlaps are the fraction of the POLYGON in each grid cell
            overlaps[ii,jj] = overlap_cell.area/fire_shape.area
    
    return overlaps

# %%
#geoseries way
        #load in the relevant geometry array
        geojson_path = path.replace('.'+yr+mo+dy+'.nc4', '_grid_polygons.geojson')
        geojson_path = geojson_path.replace('/data2/lthapa/'+yr+'/MERRA2/', './')
        geojson_path = geojson_path.replace('/data2/lthapa/'+yr+'/QFED/', './')
        print(geojson_path)
        grid_polys = gpd.read_file(geojson_path)
        
inds = np.where(grid_polys['geometry'].intersection(poly).area)[0]
            areas = grid_polys['geometry'].intersection(poly).area
            #print(areas[inds])
            #print(areas[inds]/poly.area)
            toc=time.time()
            print('Time elapsed for calculating overlaps for polygon:', toc-tic)
