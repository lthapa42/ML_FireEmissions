# %% [markdown]
# This notebook merges the SNPP and NOAA-20 VIIRS detections

# %%
import pandas as pd
#pd.set_option("display.max_rows", None, "display.max_columns", None)
from datetime import datetime, timedelta

# %%
#viirs_n20 = pd.read_csv('../fire_nrt_J1V-C2_230186.csv')
viirs_n20=pd.read_csv('../fire_nrt_J1V-C2_221507.csv')
#viirs_snpp = pd.read_csv('../fire_archive_SV-C2_230187.csv')
viirs_snpp = pd.read_csv('../fire_archive_SV-C2_221508.csv')

#print(viirs_n20.dtypes)
#print(viirs_snpp.dtypes)
print(viirs_n20)
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       31.36244 -101.77902       323.6  0.46   0.39  2019-12-04       842
# 1       31.38544 -103.64748       298.0  0.40   0.37  2019-12-04       842
# 2       31.80427 -104.12467       303.7  0.39   0.36  2019-12-04       842
# 3       32.40633 -101.54912       315.3  0.46   0.39  2019-12-04       842
# 4       31.80359 -104.12057       300.8  0.39   0.36  2019-12-04       842
# ...          ...        ...         ...   ...    ...         ...       ...
# 460929  38.26525 -120.71162       332.0  0.51   0.41  2020-12-31      2036
# 460930  39.21318 -121.62806       333.8  0.54   0.42  2020-12-31      2036
# 460931  37.79910 -121.14533       330.3  0.55   0.42  2020-12-31      2036
# 460932  34.33340 -118.52022       327.2  0.48   0.40  2020-12-31      2036
# 460933  37.87091 -120.22929       328.1  0.50   0.41  2020-12-31      2036
#
#         satellite instrument confidence version  bright_t31  frp daynight
# 0               1      VIIRS          n  2.0NRT       278.1  1.2        N
# 1               1      VIIRS          n  2.0NRT       271.1  0.6        N
# 2               1      VIIRS          n  2.0NRT       274.7  0.6        N
# 3               1      VIIRS          n  2.0NRT       276.2  1.6        N
# 4               1      VIIRS          n  2.0NRT       273.9  0.8        N
# ...           ...        ...        ...     ...         ...  ...      ...
# 460929          1      VIIRS          n  2.0NRT       284.7  4.2        D
# 460930          1      VIIRS          n  2.0NRT       282.3  4.4        D
# 460931          1      VIIRS          n  2.0NRT       279.3  1.8        D
# 460932          1      VIIRS          n  2.0NRT       289.3  2.2        D
# 460933          1      VIIRS          n  2.0NRT       285.7  7.6        D
#
# [460934 rows x 14 columns]
# /home/lthapa/anaconda3/envs/ML_py/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(viirs_n20.shape, viirs_snpp.shape)
viirs_all = pd.concat([viirs_n20, viirs_snpp], axis = 0)
print(viirs_all.shape)
viirs_all.to_csv('merged_viirs.csv', index=False)
# Out:
# (460934, 14) (604343, 15)
# (1065277, 15)

# %%
viirs_all
# Out:
#         latitude   longitude  brightness  scan  track    acq_date  acq_time  \
# 0      31.362440 -101.779020      323.60  0.46   0.39  2019-12-04       842
# 1      31.385440 -103.647480      298.00  0.40   0.37  2019-12-04       842
# 2      31.804270 -104.124670      303.70  0.39   0.36  2019-12-04       842
# 3      32.406330 -101.549120      315.30  0.46   0.39  2019-12-04       842
# 4      31.803590 -104.120570      300.80  0.39   0.36  2019-12-04       842
# ...          ...         ...         ...   ...    ...         ...       ...
# 40540 -33.229168   24.420395      327.66  0.39   0.44  2019-01-01      2348
# 40541 -33.225536   24.425417      305.16  0.39   0.44  2019-01-01      2348
# 40542 -33.225094   24.421232      317.47  0.39   0.44  2019-01-01      2348
# 40543 -33.224190   24.412716      309.56  0.39   0.44  2019-01-01      2348
# 40544 -32.124332   22.654032      341.55  0.47   0.40  2019-01-01      2348
#
#       satellite instrument confidence version  bright_t31   frp daynight  type
# 0             1      VIIRS          n  2.0NRT      278.10  1.20        N   NaN
# 1             1      VIIRS          n  2.0NRT      271.10  0.60        N   NaN
# 2             1      VIIRS          n  2.0NRT      274.70  0.60        N   NaN
# 3             1      VIIRS          n  2.0NRT      276.20  1.60        N   NaN
# 4             1      VIIRS          n  2.0NRT      273.90  0.80        N   NaN
# ...         ...        ...        ...     ...         ...   ...      ...   ...
# 40540         N      VIIRS          n       1      289.00  1.76        N   0.0
# 40541         N      VIIRS          n       1      287.83  1.76        N   0.0
# 40542         N      VIIRS          n       1      288.56  1.76        N   0.0
# 40543         N      VIIRS          n       1      287.73  1.20        N   0.0
# 40544         N      VIIRS          n       1      288.99  3.15        N   0.0
#
# [501479 rows x 15 columns]
